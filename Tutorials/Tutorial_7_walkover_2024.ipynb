# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# * [Ref] https://www.kaggle.com/code/spscientist/a-simple-tutorial-on-exploratory-data-analysis#A-Simple-Tutorial-on-Exploratory-Data-Analysis
#
# * Univariate
# * Bivariate
# * Multivariate

# %% [markdown]
# ## 0. Data initialization

# %%
import numpy as np
import pandas as pd


from google.colab import drive
drive.mount('/content/drive')

df_salary = pd.read_csv('/content/drive/MyDrive/Dataset/salary_cleaned.csv') #load the csv dataset into a 'dataframe' df
df_xtra_info = pd.read_csv('/content/drive/MyDrive/Dataset/xtra_info.csv') #load the csv dataset into a 'dataframe' df

print(len(df_salary))
print(len(df_xtra_info))

df_master = pd.concat([df_salary,df_xtra_info],axis=1)
print(len(df_master))
df_master.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 13404
# 13404
# 13404
#    USERID           Timestamp    Age                       Industry  \
# 0    8683  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1    3880  4/27/2021 11:02:41  25-34                     Nonprofits
# 2    8898  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 3    4441  4/27/2021 11:03:01  45-54              Computing or Tech
# 4    7537  4/27/2021 11:03:02  35-44  Accounting, Banking & Finance
#
#                             Job title    Salary  Compensation Currency  \
# 0  Research and Instruction Librarian   55000.0           0.0      USD
# 1                     Program Manager   62000.0        3000.0      USD
# 2                  Accounting Manager   60000.0        7000.0      USD
# 3                     Systems Analyst  112000.0       10000.0      USD
# 4                   Senior Accountant   45000.0           0.0      USD
#
#          Country           State        City Overall years of experience  \
# 0  United States   Massachusetts      Boston                   5-7 years
# 1            USA       Wisconsin   Milwaukee                8 - 10 years
# 2             US  South Carolina  Greenville                8 - 10 years
# 3             US        Missouri   St. Louis               21 - 30 years
# 4  United States         Florida  Palm Coast               21 - 30 years
#
#   Years of experience in current job  Education level Gender  USERID  \
# 0                          5-7 years  Master's degree  Woman    8683
# 1                          5-7 years   College degree  Woman    3880
# 2                          5-7 years   College degree  Woman    8898
# 3                      21 - 30 years   College degree  Woman    4441
# 4                      21 - 30 years   College degree  Woman    7537
#
#        CGPA  Salary_month_USD  Special Bonus_GBP
# 0  2.990627       4583.333333             2437.0
# 1  2.288131       5166.666667              740.0
# 2  3.903324       5000.000000             3806.0
# 3  2.470852       9333.333333             4691.0
# 4  3.559457       3750.000000             4580.0

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13404 entries, 0 to 13403
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   USERID                              13404 non-null  int64
#  1   Timestamp                           13403 non-null  object
#  2   Age                                 13403 non-null  object
#  3   Industry                            13403 non-null  object
#  4   Job title                           13403 non-null  object
#  5   Salary                              13403 non-null  float64
#  6   Compensation                        13403 non-null  float64
#  7   Currency                            13403 non-null  object
#  8   Country                             13403 non-null  object
#  9   State                               13403 non-null  object
#  10  City                                13403 non-null  object
#  11  Overall years of experience         13403 non-null  object
#  12  Years of experience in current job  13403 non-null  object
#  13  Education level                     13403 non-null  object
#  14  Gender                              13403 non-null  object
#  15  USERID                              13404 non-null  int64
#  16  CGPA                                13403 non-null  float64
#  17  Salary_month_USD                    13403 non-null  float64
#  18  Special Bonus_GBP                   13403 non-null  float64
# dtypes: float64(5), int64(2), object(12)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Analyzing each feature/columns

# %%
df_master.columns
df_master = df_master.drop(columns='USERID')
df_master.columns
# Out:
# Index(['Timestamp', 'Age', 'Industry', 'Job title', 'Salary', 'Compensation',
#        'Currency', 'Country', 'State', 'City', 'Overall years of experience',
#        'Years of experience in current job', 'Education level', 'Gender',
#        'CGPA', 'Salary_month_USD', 'Special Bonus_GBP'],
#       dtype='object')

# %% [markdown]
# # Univariate

# %% [markdown]
# ## Numerical data

# %%
#You will need this for scatter matrix later
df_numerical = df_master[['Salary','Compensation','Salary_month_USD','CGPA','Special Bonus_GBP']]

# %% [markdown]
# ### Summary statistics

# %%
df_master.describe()
#df_numerical.describe()
# Out:
#               Salary  Compensation          CGPA  Salary_month_USD  \
# count   13403.000000  13403.000000  13403.000000      13403.000000
# mean    81539.461315   4155.284936      2.992438       6794.955110
# std     28134.315890   5778.882891      0.575155       2344.526324
# min     37860.000000      0.000000      2.000039       3155.000000
# 25%     59000.000000      0.000000      2.500295       4916.666667
# 50%     76000.000000   1500.000000      2.984247       6333.333333
# 75%    100000.000000   6000.000000      3.484162       8333.333333
# max    151374.000000  25500.000000      3.999992      12614.500000
#
#        Special Bonus_GBP
# count       13403.000000
# mean         2501.569798
# std          1438.749945
# min             0.000000
# 25%          1264.500000
# 50%          2506.000000
# 75%          3761.500000
# max          5000.000000

# %%
# If the median < mean , is the distribution skewed to the left or right?

# %% [markdown]
# ### Histograms and boxplots

# %%
df_master.hist(figsize=(10,5))
#df_master["Salary"].hist()
# Out:
# <Axes: >

# %%
df_master.boxplot(figsize=(10,5))
# Out:
# <Axes: >

# %%
#df_master['Salary'].hist()
df_master['Salary'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ## Categorial data

# %%
df_categorical =  df_master.select_dtypes(include=['object'])
df_categorical.head()
# Out:
#             Timestamp    Age                       Industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:41  25-34                     Nonprofits
# 2  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:03:01  45-54              Computing or Tech
# 4  4/27/2021 11:03:02  35-44  Accounting, Banking & Finance
#
#                             Job title Currency        Country           State  \
# 0  Research and Instruction Librarian      USD  United States   Massachusetts
# 1                     Program Manager      USD            USA       Wisconsin
# 2                  Accounting Manager      USD             US  South Carolina
# 3                     Systems Analyst      USD             US        Missouri
# 4                   Senior Accountant      USD  United States         Florida
#
#          City Overall years of experience Years of experience in current job  \
# 0      Boston                   5-7 years                          5-7 years
# 1   Milwaukee                8 - 10 years                          5-7 years
# 2  Greenville                8 - 10 years                          5-7 years
# 3   St. Louis               21 - 30 years                      21 - 30 years
# 4  Palm Coast               21 - 30 years                      21 - 30 years
#
#    Education level Gender
# 0  Master's degree  Woman
# 1   College degree  Woman
# 2   College degree  Woman
# 3   College degree  Woman
# 4   College degree  Woman

# %%
#df_categorical['Industry'].value_counts().plot(kind='bar')
#df_categorical['Industry'].value_counts().plot(kind='pie')
x = df_categorical['Industry'].value_counts()

#x[x>100].plot(kind='bar')

#print(x.idxmax())


x_df = x.to_frame(name='Count')  # Convert Series to DataFrame with column name 'Count'
x_df['Percentage'] = x_df['Count'] / x_df['Count'].sum() * 100  # Add a new column 'Percentage' to the DataFrame
x_df
#x_df.head()

x_df[x_df['Percentage']>1].plot(kind='bar')  #try with this. what happens?
#x_df[x_df['Percentage']>1]['Percentage'].plot(kind='bar')
# Out:
# <Axes: xlabel='Salary', ylabel='Compensation'>

# %% [markdown]
# ## Bivariate analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.pairplot(df_numerical, diag_kind="hist", plot_kws={'alpha':0.7})
plt.suptitle("Pairwise Scatter Plots and Histograms", y=1.02, fontsize=16)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(df_master, figsize=(12,12))
plt.show()

# %% [markdown]
# # Multivariate

# %% [markdown]
# ## Correlation analysis

# %%
df_numerical.corr()  #by default, the method is called Pearson.

# What is the difference between Pearson and Spearman
# Out:
#                      Salary  Compensation  Salary_month_USD      CGPA  \
# Salary             1.000000      0.411829          1.000000  0.005361
# Compensation       0.411829      1.000000          0.411829 -0.012784
# Salary_month_USD   1.000000      0.411829          1.000000  0.005361
# CGPA               0.005361     -0.012784          0.005361  1.000000
# Special Bonus_GBP  0.001906     -0.001833          0.001906  0.004139
#
#                    Special Bonus_GBP
# Salary                      0.001906
# Compensation               -0.001833
# Salary_month_USD            0.001906
# CGPA                        0.004139
# Special Bonus_GBP           1.000000

# %%
df_numerical.corr(method='spearman')
# Out:
#                      Salary  Compensation  Salary_month_USD      CGPA  \
# Salary             1.000000      0.334234          1.000000  0.005788
# Compensation       0.334234      1.000000          0.334234 -0.004313
# Salary_month_USD   1.000000      0.334234          1.000000  0.005788
# CGPA               0.005788     -0.004313          0.005788  1.000000
# Special Bonus_GBP  0.002990      0.005093          0.002990  0.004171
#
#                    Special Bonus_GBP
# Salary                      0.002990
# Compensation                0.005093
# Salary_month_USD            0.002990
# CGPA                        0.004171
# Special Bonus_GBP           1.000000

# %%
df_numerical.corr(method='kendall')
# Out:
#                      Salary  Compensation  Salary_month_USD      CGPA  \
# Salary             1.000000      0.246944          1.000000  0.003852
# Compensation       0.246944      1.000000          0.246944 -0.003093
# Salary_month_USD   1.000000      0.246944          1.000000  0.003852
# CGPA               0.003852     -0.003093          0.003852  1.000000
# Special Bonus_GBP  0.001969      0.003541          0.001969  0.002767
#
#                    Special Bonus_GBP
# Salary                      0.001969
# Compensation                0.003541
# Salary_month_USD            0.001969
# CGPA                        0.002767
# Special Bonus_GBP           1.000000
