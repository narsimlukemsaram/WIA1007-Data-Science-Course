# %% [markdown]
# # Asking questions and getting to know your data

# %%
# Some tips on coding
# 1. Check for typos -  for example the code is  'print' not 'prin'
# 2. Check for space -  for example the code is  print('hello')  not print ('hello')
# 3. Always use GPT/Gemini/Google for answer - for example 'how to load dataset in Python'

# %% [markdown]
# # 1. Find some real dataset. Load it on Colab, Kaggle etc. Try to visualize some of it

# %% [markdown]
# [Source] https://oscarbaruffa.com/messy/
#
# I've renamed the column of the dataset (using excel because we haven't learn data preprocessing yet)

# %%
import pandas as pd # this is importing python/pandas library

#pd.read_csv() is a function called from pandas library


from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/Dataset/salary.csv') # this command load salary.csv onto your dataframe named as df.
df.head() #this show top rows

# What is the dataset about- The dataset is about salary and what seems to be determining it.
# As a Data Scientist, you can take up the role of Human Resource here in getting to know how much to pay your employee's salary based on different features.
# As a Data Scientist/Analyst, you should be asking, what determines whether a person get paid a high salary or not? Is it education level?Age?Where he lives?
# As a Data Scientist/Analyst, it is your job to be critical. For example, you can ask, are women and men paid the same across all ages? Which industry pays the
# highest?
# One tip on how to ask questions, is BY LOOKING AT THE FEATURES/COLUMNS of your data.
# Out:
# Mounted at /content/drive
#             Timestamp    Age                       Industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                   Job title Context  Salary  Compensation  \
# 0        Research and Instruction Librarian     NaN  55,000           0.0
# 1  Change & Internal Communications Manager     NaN  54,600        4000.0
# 2                      Marketing Specialist     NaN  34,000           NaN
# 3                           Program Manager     NaN  62,000        3000.0
# 4                        Accounting Manager     NaN  60,000        7000.0
#
#   Currency Other currency Salary context         Country           State  \
# ...

# %%
# Look at the dataframe above, The number on the most left is called 'index'. And each Column has a name which you can use to call the columns

# %%
#df['Age'].nunique() # This extracts the number of unique values in this column
df['Age'].unique() # This extracts all the unique values. Convenient for categorical data. Messy for non categorical
#df['Compensation'].nunique()

print(df['Currency'].nunique())
print(df['Currency'].unique())

print(df['Compensation'].nunique())
# Out:
# 11
# ['USD' 'GBP' 'CAD' 'EUR' 'AUD/NZD' 'Other' 'CHF' 'ZAR' 'SEK' 'HKD' 'JPY']
# 843

# %%
df['Compensation'].unique()
df[df['Compensation']<20000].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # 2. Evaluate if the data is good or not. Does it have enough samples? (Data Types)

# %%
df.info()
# How to determine a good dataset? A dataset is commonly considered good if it has enough samples and the columns are informative.
# As a Data scientist you must study the columns, are they informative? For example, if the column consist if user_id, then it is non informative (why?)
# For the dataframe above, which are the informative and non informative columns?
# To answer the question , I think the salary dataset is good (eventhough messy) because there are many informative columns such as Age, Gender, Education level.
# A column is informative if it is relevant to our question, i.e Education level is relevant in determining the amount of salary, hence informative. But timestamp is not informative

### Does it have enough samples?###
# The dataset has 27,989 samples, or rows of observations with 18 columns. Since the samples is almost 30k, i think
# the number of sample is enough
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27989 entries, 0 to 27988
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Timestamp                           27989 non-null  object
#  1   Age                                 27989 non-null  object
#  2   Industry                            27917 non-null  object
#  3   Job title                           27989 non-null  object
#  4   Context                             7240 non-null   object
#  5   Salary                              27989 non-null  object
#  6   Compensation                        20719 non-null  float64
#  7   Currency                            27989 non-null  object
#  8   Other currency                      197 non-null    object
#  9   Salary context                      3034 non-null   object
#  10  Country                             27989 non-null  object
# ...

# %% [markdown]
# # 3. How many features does it have? Is it enough?

# %%
# From df.info() the dataset has 18 columns. So we will have 17 features determining 1 target output (target output=salary).
# 17 features is enough, from experience must need at least 4/5 features and above

# %% [markdown]
# # 4. How many samples/observation does it have? Is it enough?

# %%
# From df.info() it has 27,879 samples.
# From experience, the minimum number of samples is best set at 100 samples. If you have 1000 samples that is good enough. 10,000 samples is very good.
# So our salary data has enough samples

# %% [markdown]
# # 5a. What are the Types of Data(format, maths properties)

# %% [markdown]
# # 5b. What are the Data Types ?

# %%
# To answer this question, we look again at df.info()
# As you can see from below, most of the columns consists of 'object' datatypes i.e strings as in 'abcde'
# Only ONE column has numbers which is the 'Compensation' in the format of float64
# Funny enough, the column 'Salary' is not in number format (either int or float) but is an object. We will need to convert this later.(Preprocessing)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27989 entries, 0 to 27988
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Timestamp                           27989 non-null  object
#  1   Age                                 27989 non-null  object
#  2   Industry                            27917 non-null  object
#  3   Job title                           27989 non-null  object
#  4   Context                             7240 non-null   object
#  5   Salary                              27989 non-null  object
#  6   Compensation                        20719 non-null  float64
#  7   Currency                            27989 non-null  object
#  8   Other currency                      197 non-null    object
#  9   Salary context                      3034 non-null   object
#  10  Country                             27989 non-null  object
# ...

# %% [markdown]
# # 6. How many columns have Null/NaN values? If yes, which column, which rows
#
# * A null values is an empty value.
# * It is not the same as zero. For example x=0 is zero values.
# * But x = '' (empty, nothing in between the quotation marks, not even a whitespace) is a Null values.
# * Null is displayed as NaN in Python
# * Extra reading https://www.thedataschool.co.uk/shahbaz-khan/difference-between-null-and-missing-data/

# %%
df.info()

# One of the fastest way to check which columns has null values is by using df.info()
# As you can see below we have 27,989 rows and 18 columns.
# Look at the Non-Null Count for each column. If the non-null count is the same as the total number of rows, that means that the column does not have any Null values
# For example, 'Age' does not have null values
# But 'Context' only has 7240 non-null values. So it has 27,989total rows-7240non null rows = 20,749 Null Values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27989 entries, 0 to 27988
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Timestamp                           27989 non-null  object
#  1   Age                                 27989 non-null  object
#  2   Industry                            27917 non-null  object
#  3   Job title                           27989 non-null  object
#  4   Context                             7240 non-null   object
#  5   Salary                              27989 non-null  object
#  6   Compensation                        20719 non-null  float64
#  7   Currency                            27989 non-null  object
#  8   Other currency                      197 non-null    object
#  9   Salary context                      3034 non-null   object
#  10  Country                             27989 non-null  object
# ...

# %% [markdown]
# ## 6.1 Selecting subset of a dataset
#
# ### 6.1.1 Selecting subset columns

# %%
df.head(2)
# Out:
#             Timestamp    Age                      Industry  \
# 0  4/27/2021 11:02:10  25-34  Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34             Computing or Tech
#
#                                   Job title Context  Salary  Compensation  \
# 0        Research and Instruction Librarian     NaN  55,000           0.0
# 1  Change & Internal Communications Manager     NaN  54,600        4000.0
#
#   Currency Other currency Salary context         Country          State  \
# 0      USD            NaN            NaN   United States  Massachusetts
# 1      GBP            NaN            NaN  United Kingdom            NaN
#
#         City Overall years of experience Years of experience in current job  \
# 0     Boston                   5-7 years                          5-7 years
# 1  Cambridge                8 - 10 years                          5-7 years
#
#    Education level      Gender   Race
# 0  Master's degree       Woman  White
# ...

# %%
#Let's focus on 'Context' column

# We can select a specific column by using the code df[['column_name']]. Example below
x = df[['Salary']]
x.head()

#The result takes only one column as below. Lots of NaN/Null values.
# Out:
#    Salary
# 0  55,000
# 1  54,600
# 2  34,000
# 3  62,000
# 4  60,000

# %%
# If we want to select a subset of 2 columns we can do df[['column_1','column_2']]
x = df[['Age','Context','Salary']]
x.head()

#So if we want to do 3 columns, just add df[['column_1','column_2]','column_3','column_4']
# Out:
#      Age Context  Salary
# 0  25-34     NaN  55,000
# 1  25-34     NaN  54,600
# 2  25-34     NaN  34,000
# 3  25-34     NaN  62,000
# 4  25-34     NaN  60,000

# %% [markdown]
# ### 6.1.2 Selecting subset of rows (which meets a certain condition)

# %%
# But let's say we want to select a row that meets a certain condition.
# Let's say we want to select those whose salary = 55,000
# We use df[df['column_name']==condition value]

x = df[df['Salary']=='55,000']
# Here we must be careful, because the datatype for column Salary is 'object' so what ever values in the column can be considered as a string.
# So that is why we wrapped up 55,000 with ''  in the command above
x.head()

# Say we want to select those whose salary is below 55,000
# x = df[df['Salary'] <'55,000'] ----we cannot do this because 55,000 is a string, not a number, so cannot do comparison
# Out:
#               Timestamp    Age                      Industry  \
# 0    4/27/2021 11:02:10  25-34  Education (Higher Education)
# 82   4/27/2021 11:04:55  25-34                    Nonprofits
# 133  4/27/2021 11:05:46  55-64  Education (Higher Education)
# 188  4/27/2021 11:06:24  25-34            Academic Medicine
# 212  4/27/2021 11:06:50  35-44       Commercial Real Estate
#
#                               Job title  \
# 0    Research and Instruction Librarian
# 82         Graphic Designer / Webmaster
# 133        career services professional
# 188           Administrative Specialist
# 212            Administrative Associate
#
#                                                Context  Salary  Compensation  \
# 0                                                  NaN  55,000           0.0
# 82                                                 NaN  55,000           NaN
# 133                                                NaN  55,000           NaN
# ...

# %%
#Convert string column to int. This is a little bit advance. Please ignore the 'warnings' etc


df['Salary'] = df['Salary'].replace(',','',regex=True) #this replace the comma ',' in 55,000 to 55000
df['Salary'] = df['Salary'].astype(int) # this convert the column datatypes from object into numbers , in this case integer
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27989 entries, 0 to 27988
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Timestamp                           27989 non-null  object
#  1   Age                                 27989 non-null  object
#  2   Industry                            27917 non-null  object
#  3   Job title                           27989 non-null  object
#  4   Context                             7240 non-null   object
#  5   Salary                              27989 non-null  int64
#  6   Compensation                        20719 non-null  float64
#  7   Currency                            27989 non-null  object
#  8   Other currency                      197 non-null    object
#  9   Salary context                      3034 non-null   object
#  10  Country                             27989 non-null  object
# ...

# %%
#Now only can we select those with salary less than 50000

x = df[df['Salary'] < 50000]  #no need quotation marks anymore, because Salary column is a column of number
x.head()
# Out:
#              Timestamp    Age                       Industry  \
# 2   4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 6   4/27/2021 11:02:51  25-34                     Publishing
# 9   4/27/2021 11:03:02  35-44  Accounting, Banking & Finance
# 10  4/27/2021 11:03:03  25-34                     Nonprofits
# 14  4/27/2021 11:03:11  18-24                    Health care
#
#                    Job title Context  Salary  Compensation Currency  \
# 2       Marketing Specialist     NaN   34000           NaN      USD
# 6       Publishing Assistant     NaN   33000        2000.0      USD
# 9          Senior Accountant     NaN   45000           0.0      USD
# 10            Office Manager     NaN   47500           0.0      USD
# 14  Patient care coordinator     NaN   32000           NaN      CAD
#
#    Other currency               Salary context        Country           State  \
# 2             NaN                          NaN             US       Tennessee
# ...

# %% [markdown]
# ### 6.1.3 Selecting a subset of rows with Null/NaN values

# %%
# Back to the question, which column, which row has null values?
# We know the column 'Context' has NaN values

x = df['Context']  # we assign the column 'Context' from the dataframe df to variable x
x.info()
#if we look at x.info(), 27,989total rows - 7240non null rows = 20,749 null rows
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 27989 entries, 0 to 27988
# Series name: Context
# Non-Null Count  Dtype
# --------------  -----
# 7240 non-null   object
# dtypes: object(1)
# memory usage: 218.8+ KB

# %%
#To get the rows of the null values
# https://datatofish.com/rows-with-nan-pandas-dataframe/
# When we do x.isna(), it returns a column where if the row is NaN, that row will be marked as True. Else, it will mark the row as False
# When we do x[x.isna()], it makes a list of all rows that is True i.e the NaN rows.
y = x[x.isna()]
y
#As you can see, the length of y is 20,749. This Tallies with our answer above.
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 27984    NaN
# 27985    NaN
# 27986    NaN
# 27987    NaN
# 27988    NaN
# Name: Context, Length: 20749, dtype: object

# %% [markdown]
# # 7. Which column is the feature, which is the target output?

# %%
df.info()
# We have answered this in number 1. What are the features/columns that determine the salary of a person?
# In this case, the dataset has 18 features (not all of them are informative as discussed before. For example, timestamp is not an informative feature)
# Column 0-4 and 6-17 are the features
# Column 5: 'salary' is the target output
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27989 entries, 0 to 27988
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Timestamp                           27989 non-null  object
#  1   Age                                 27989 non-null  object
#  2   Industry                            27917 non-null  object
#  3   Job title                           27989 non-null  object
#  4   Context                             7240 non-null   object
#  5   Salary                              27989 non-null  int64
#  6   Compensation                        20719 non-null  float64
#  7   Currency                            27989 non-null  object
#  8   Other currency                      197 non-null    object
#  9   Salary context                      3034 non-null   object
#  10  Country                             27989 non-null  object
# ...

# %% [markdown]
# # 9. What kind of question can be asked, should we ask. Does the dataset suits the question we are asking?

# %%
# We've also discussed this briefly. Imagine you are the Human resource, or a business owner. How much would you need to pay an employee given his education
# level=diploma, age=27, years of explerience = 5 etc.?

# %% [markdown]
# # 10. Questions from Data: (1) How to pay my employee as competitively as legally as possible?
#
# Assume that you are the CEO of a tech company.

# %%
df[df['Industry']=='Computing or Tech'].head()
# Out:
#              Timestamp    Age           Industry  \
# 1   4/27/2021 11:02:22  25-34  Computing or Tech
# 8   4/27/2021 11:03:01  45-54  Computing or Tech
# 43  4/27/2021 11:04:04  25-34  Computing or Tech
# 44  4/27/2021 11:04:04  25-34  Computing or Tech
# 46  4/27/2021 11:04:07  35-44  Computing or Tech
#
#                                    Job title                       Context  \
# 1   Change & Internal Communications Manager                           NaN
# 8                            Systems Analyst  Data developer/ETL Developer
# 43               Principal Software Engineer                           NaN
# 44                      Intelligence Analyst                           NaN
# 46                          Mobile developer                           NaN
#
#     Salary  Compensation Currency Other currency  \
# 1    54600        4000.0      GBP            NaN
# 8   112000       10000.0      USD            NaN
# 43  187500        5000.0      USD            NaN
# ...

# %%
df[df['Job title']=='System Analyst']
# Out:
#                 Timestamp    Age                       Industry  \
# 1696   4/27/2021 11:30:17  25-34  Accounting, Banking & Finance
# 4391   4/27/2021 12:32:54  55-64              Computing or Tech
# 20397  4/29/2021 14:09:19  45-54              Computing or Tech
# 25447      5/6/2021 15:47  35-44         Business or Consulting
# 26335  5/25/2021 10:47:06  45-54                    Health care
#
#             Job title                                            Context  \
# 1696   System Analyst                                                NaN
# 4391   System Analyst                                                NaN
# 20397  System Analyst  Business Analyst or Business Systems Analyst a...
# 25447  System Analyst                                                NaN
# 26335  System Analyst                                                NaN
#
#        Salary  Compensation Currency Other currency Salary context  \
# 1696    75000        5000.0      USD            NaN            NaN
# ...
